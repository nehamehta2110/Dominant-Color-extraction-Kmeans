# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs

# %%
X, _ = make_blobs(n_samples=1000, centers=5)
print (X.shape)
# Out:
# (1000, 2)

# %%
plt.figure()
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
k = 5

colors = ['pink','blue','green','red','orange']

clusters = {}

for ix in range(k):
    center = 10.0*(2*np.random.random( (X.shape[1],) ) -1)
    points = []
    
    cluster = {
        "center" : center,
        "points" : points,
        "color" : colors[ix]        
    }
    
    clusters[ix] = cluster
    
print (clusters)
# Out:
# {0: {'center': array([-1.38539827, -0.26550835]), 'points': [], 'color': 'pink'}, 1: {'center': array([-7.55021076,  4.3132679 ]), 'points': [], 'color': 'blue'}, 2: {'center': array([ 7.12678329, -6.20475861]), 'points': [], 'color': 'green'}, 3: {'center': array([-7.54940431,  3.18882076]), 'points': [], 'color': 'red'}, 4: {'center': array([-0.77094298,  7.28020581]), 'points': [], 'color': 'orange'}}

# %%
plt.figure()
plt.scatter(X[:,0],X[:,1])
for ix in range(k):
    plt.scatter(clusters[ix]["center"][0], clusters[ix]["center"][1], color = "black", marker = "*", s=100)
plt.show()

# %%
def distance(v1,v2):
    return np.sqrt( np.sum( (v1-v2)**2 ) )

# %%
for ix in range(X.shape[0]):
    
    dis = []
    curr_p = X[ix]
    
    for kx in range(k):
        d = distance(curr_p, clusters[kx]["center"])
        dis.append(d)
        
    assined_cluster = np.argmin(dis)
        
    clusters[assined_cluster]["points"].append(curr_p)

    
for kx in range(k):
    pnts = np.array(clusters[kx]["points"])
    
    clusters[kx]["coords"] = pnts
    
plt.figure(0)
for kx in range(k):
    pts = clusters[kx]["coords"]
    
    try:
        plt.scatter(pts[:,0],pts[:,1], color = clusters[kx]["color"])
    except:
        pass
    
    plt.scatter(clusters[kx]["center"][0], clusters[kx]["center"][1], color = "black", marker = "*", s=100)
    

for kx in range(k):
    
    if clusters[kx]["coords"].shape[0]>0:
        new_center = clusters[kx]["coords"].mean(axis=0)
    else:
        new_center = clusters[kx]["center"]
        
    clusters[kx]["center"] = new_center
    clusters[kx]["points"] = []
    
plt.figure(1)
for kx in range(k):
    pts = clusters[kx]["coords"]
    
    try:
        plt.scatter(pts[:,0],pts[:,1], color = clusters[kx]["color"])
    except:
        pass
    
    plt.scatter(clusters[kx]["center"][0], clusters[kx]["center"][1], color = "black", marker = "*", s=100)
    
plt.show()

# %% [markdown]
# ## SKLEARN

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=5)

# %%
z = kmeans.fit_transform(X)

# %%
cen = kmeans.cluster_centers_

# %%
Y = kmeans.labels_

# %%
plt.figure()

plt.scatter(X[:,0],X[:,1], c = Y)
plt.scatter(cen[:,0], cen[:,1], marker="*",s=100,color='black')
plt.show()
